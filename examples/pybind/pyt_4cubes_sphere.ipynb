# %%
from march.module import DMC
import torch
import open3d as o3d
import numpy as np
import plotly.graph_objects as go

# %%
sphere_mesh = o3d.geometry.TriangleMesh.create_sphere(radius=1.0, resolution=20)

print("# vertices:", len(sphere_mesh.vertices))
print("# triangles:", len(sphere_mesh.triangles))
# Out:
# # vertices: 762
# # triangles: 1520
